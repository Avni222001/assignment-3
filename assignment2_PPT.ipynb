# %% [markdown]
# *1.*
#
# To calculate the mean sales for each region, you need to sum up the sales figures for each region and divide by the number of data points. Here's how you can calculate the mean sales for Region A and Region B using the given data:
#
# Region A: [10, 15, 12, 8, 14]
# To calculate the mean sales for Region A, add up all the sales figures and divide by the total number of data points (in this case, 5).
#
# Mean sales for Region A = (10 + 15 + 12 + 8 + 14) / 5 = 59 / 5 = 11.8
#
# Therefore, the mean sales for Region A is 11.8.
#
# Region B: [18, 20, 16, 22, 25]
# Similarly, for Region B, add up all the sales figures and divide by the total number of data points (again, 5 in this case).
#
# Mean sales for Region B = (18 + 20 + 16 + 22 + 25) / 5 = 101 / 5 = 20.2
#
# Therefore, the mean sales for Region B is 20.2.
#
# So, the mean sales for Region A is 11.8, and the mean sales for Region B is 20.2.

# %% [markdown]
# *2.*
#
#
# To calculate the mode of the survey responses, you need to identify the value that appears most frequently in the data. In this case, the data is as follows:
#
# [4, 5, 2, 3, 5, 4, 3, 2, 4, 5]
#
# To find the mode, you can count the occurrences of each unique value and determine which value has the highest frequency. Let's calculate it step by step:
#
# Value: 4, Frequency: 3
# Value: 5, Frequency: 3
# Value: 2, Frequency: 2
# Value: 3, Frequency: 2
#
# From the calculations above, we can see that both 4 and 5 appear three times in the data, which is more than any other value. Therefore, the mode of the survey responses is 4 and 5.
#
# Note: It's possible to have multiple modes or no mode at all if no value appears more frequently than the others. In this case, 4 and 5 are the modes because they have the highest frequency.

# %% [markdown]
# *3.*
#
# To calculate the median salary for each department, you need to arrange the salary data in ascending order and find the middle value. If there is an odd number of data points, the median is the middle value. If there is an even number of data points, the median is the average of the two middle values. Here's how you can calculate the median salary for Department A and Department B using the given data:
#
# Department A: [5000, 6000, 5500, 7000]
# First, sort the salaries in ascending order: [5000, 5500, 6000, 7000]
#
# Since there are four data points, the median is the average of the two middle values:
# Median salary for Department A = (5500 + 6000) / 2 = 11500 / 2 = 5750
#
# Therefore, the median salary for Department A is 5750.
#
# Department B: [4500, 5500, 5800, 6000, 5200]
# First, sort the salaries in ascending order: [4500, 5200, 5500, 5800, 6000]
#
# Since there are five data points, the median is the middle value:
# Median salary for Department B = 5500
#
# Therefore, the median salary for Department B is 5500.
#
# So, the median salary for Department A is 5750, and the median salary for Department B is 5500.

# %% [markdown]
# *4.*
#
# To calculate the range of the stock prices, you need to find the difference between the highest and lowest values in the data. Here's how you can calculate the range using the given data:
#
# Data: [25.5, 24.8, 26.1, 25.3, 24.9]
#
# Step 1: Sort the data in ascending order: [24.8, 24.9, 25.3, 25.5, 26.1]
#
# Step 2: Find the highest value (maximum): 26.1
#
# Step 3: Find the lowest value (minimum): 24.8
#
# Step 4: Calculate the range by subtracting the lowest value from the highest value:
#
# Range = 26.1 - 24.8 = 1.3
#
# Therefore, the range of the stock prices is 1.3.

# %% [markdown]
# *5.*
#
# To perform a t-test and determine if there is a significant difference in the mean scores between two groups, we can use the independent two-sample t-test. The independent t-test compares the means of two independent groups to see if there is a statistically significant difference between them. Here's how you can perform the t-test using the given data for Group A and Group B:
#
# Group A: [85, 90, 92, 88, 91]
# Group B: [82, 88, 90, 86, 87]
#
# Step 1: Calculate the mean scores for each group.
# Mean score for Group A:
# (85 + 90 + 92 + 88 + 91) / 5 = 88.4
#
# Mean score for Group B:
# (82 + 88 + 90 + 86 + 87) / 5 = 86.6
#
# Step 2: Calculate the standard deviation for each group.
# Standard deviation for Group A:
# First, calculate the squared difference between each score and the mean:
# (85 - 88.4)^2, (90 - 88.4)^2, (92 - 88.4)^2, (88 - 88.4)^2, (91 - 88.4)^2
#
# Then, calculate the sum of these squared differences:
# Sum = (85 - 88.4)^2 + (90 - 88.4)^2 + (92 - 88.4)^2 + (88 - 88.4)^2 + (91 - 88.4)^2
#
# Divide the sum by the number of scores minus 1, and take the square root:
# sqrt(Sum / (5 - 1)) = sqrt(9.2) = 3.033
#
# Standard deviation for Group B:
# First, calculate the squared difference between each score and the mean:
# (82 - 86.6)^2, (88 - 86.6)^2, (90 - 86.6)^2, (86 - 86.6)^2, (87 - 86.6)^2
#
# Then, calculate the sum of these squared differences:
# Sum = (82 - 86.6)^2 + (88 - 86.6)^2 + (90 - 86.6)^2 + (86 - 86.6)^2 + (87 - 86.6)^2
#
# Divide the sum by the number of scores minus 1, and take the square root:
# sqrt(Sum / (5 - 1)) = sqrt(7.8) = 2.79
#
# Step 3: Calculate the t-value using the formula:
# t = (mean of Group A - mean of Group B) / sqrt((standard deviation of Group A^2 / n1) + (standard deviation of Group B^2 / n2))
#
# t = (88.4 - 86.6) / sqrt((3.033^2 / 5) + (2.79^2 / 5))
#
# Step 4: Determine the degrees of freedom (df) using the formula:
# df = n1 + n2 - 2
#
# df = 5 + 5 - 2 = 8
#
# Step 5: Determine the critical t-value at the desired significance level (e.g., 0.05) and degrees of freedom (df).
#
# Step 6: Compare the calculated t-value with the critical t-value and determine if the difference in mean scores is statistically significant.
#
# If the calculated t-value is greater than the critical t-value, then there is a significant difference between the mean scores of the two groups. If the calculated t-value is less than the critical t-value, then there is no significant difference.
#
# Note: Since the critical t-value is not provided in the given scenario, you would need to consult a t-table or use statistical software to determine the critical t-value at the desired significance level and degrees of freedom.

# %% [markdown]
# *6.*
#
# To calculate the correlation coefficient between advertising expenditure and sales, you can use the Pearson correlation coefficient formula. Here's how you can calculate it using the given data:
#
# Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
# Sales (in thousands): [25, 30, 28, 20, 26]
#
# Step 1: Calculate the mean of the advertising expenditure and sales.
#
# Mean of advertising expenditure:
# (10 + 15 + 12 + 8 + 14) / 5 = 11.8
#
# Mean of sales:
# (25 + 30 + 28 + 20 + 26) / 5 = 25.8
#
# Step 2: Calculate the deviations from the mean for both variables.
#
# Deviation of advertising expenditure:
# 10 - 11.8 = -1.8
# 15 - 11.8 = 3.2
# 12 - 11.8 = 0.2
# 8 - 11.8 = -3.8
# 14 - 11.8 = 2.2
#
# Deviation of sales:
# 25 - 25.8 = -0.8
# 30 - 25.8 = 4.2
# 28 - 25.8 = 2.2
# 20 - 25.8 = -5.8
# 26 - 25.8 = 0.2
#
# Step 3: Calculate the product of the deviations for each pair of data points.
#
# Product of deviations:
# (-1.8 * -0.8), (3.2 * 4.2), (0.2 * 2.2), (-3.8 * -5.8), (2.2 * 0.2)
#
# Step 4: Calculate the sum of the products of deviations.
#
# Sum of products of deviations = (-1.8 * -0.8) + (3.2 * 4.2) + (0.2 * 2.2) + (-3.8 * -5.8) + (2.2 * 0.2) = 7.24
#
# Step 5: Calculate the standard deviation for both variables.
#
# Standard deviation of advertising expenditure:
# First, calculate the squared difference between each value and the mean:
# (-1.8 - 11.8)^2, (3.2 - 11.8)^2, (0.2 - 11.8)^2, (-3.8 - 11.8)^2, (2.2 - 11.8)^2
#
# Then, calculate the sum of these squared differences:
# Sum = (-1.8 - 11.8)^2 + (3.2 - 11.8)^2 + (0.2 - 11.8)^2 + (-3.8 - 11.8)^2 + (2.2 - 11.8)^2
#
# Divide the sum by the number of values minus 1, and take the square root:
# sqrt(Sum / (5 - 1)) = sqrt(56.4) = 7.513
#
# Standard deviation of sales:
# First, calculate the squared difference between each value and the mean:
# (-0.8 - 25.8)^2, (4.2 - 25.8)^2, (2.2 - 25.8)^2, (-5.8 - 25.8)^2, (0.2 - 25.8)^2
#
# Then, calculate the sum of these squared differences:
# Sum = (-0.8 - 25.8)^2 + (4.2 - 25.8)^2 + (2.2 - 25.8)^2 + (-5.8 - 25.8)^2 + (0.2 - 25.8)^2
#
# Divide the sum by the number of values minus 1, and take the square root:
# sqrt(Sum / (5 - 1)) = sqrt(608.8) = 24.676
#
# Step 6: Calculate the correlation coefficient using the formula:
# Correlation coefficient = Sum of products of deviations / (Standard deviation of advertising expenditure * Standard deviation of sales)
#
# Correlation coefficient = 7.24 / (7.513 * 24.676) ≈ 0.116
#
# Therefore, the correlation coefficient between advertising expenditure and sales is approximately 0.116.

# %% [markdown]
# *7.*
#
# To calculate the standard deviation of the heights, you can follow these steps:
#
# Data: [160, 170, 165, 155, 175, 180, 170]
#
# Step 1: Calculate the mean of the heights.
# Mean = (160 + 170 + 165 + 155 + 175 + 180 + 170) / 7 = 1175 / 7 = 167.857
#
# Step 2: Calculate the squared difference between each height and the mean.
# (160 - 167.857)^2, (170 - 167.857)^2, (165 - 167.857)^2, (155 - 167.857)^2, (175 - 167.857)^2, (180 - 167.857)^2, (170 - 167.857)^2
#
# Step 3: Calculate the sum of these squared differences.
# Sum = (160 - 167.857)^2 + (170 - 167.857)^2 + (165 - 167.857)^2 + (155 - 167.857)^2 + (175 - 167.857)^2 + (180 - 167.857)^2 + (170 - 167.857)^2 = 550.285
#
# Step 4: Divide the sum by the number of data points minus 1.
# Standard deviation = sqrt(Sum / (7 - 1)) = sqrt(550.285 / 6) ≈ 7.839
#
# Therefore, the standard deviation of the heights is approximately 7.839.

# %% [markdown]
# *8.*
#
# To perform a linear regression analysis to predict job satisfaction based on employee tenure, you can use the least squares method. Here's how you can do it using the given data:
#
# Employee Tenure (in years): [2, 3, 5, 4, 6, 2, 4]
# Job Satisfaction (on a scale of 1 to 10): [7, 8, 6, 9, 5, 7, 6]
#
# Step 1: Calculate the means of both employee tenure and job satisfaction.
#
# Mean of employee tenure:
# (2 + 3 + 5 + 4 + 6 + 2 + 4) / 7 = 26 / 7 ≈ 3.714
#
# Mean of job satisfaction:
# (7 + 8 + 6 + 9 + 5 + 7 + 6) / 7 = 48 / 7 ≈ 6.857
#
# Step 2: Calculate the deviations from the means for both variables.
#
# Deviation of employee tenure:
# 2 - 3.714 = -1.714
# 3 - 3.714 = -0.714
# 5 - 3.714 = 1.286
# 4 - 3.714 = 0.286
# 6 - 3.714 = 2.286
# 2 - 3.714 = -1.714
# 4 - 3.714 = 0.286
#
# Deviation of job satisfaction:
# 7 - 6.857 = 0.143
# 8 - 6.857 = 1.143
# 6 - 6.857 = -0.857
# 9 - 6.857 = 2.143
# 5 - 6.857 = -1.857
# 7 - 6.857 = 0.143
# 6 - 6.857 = -0.857
#
# Step 3: Calculate the product of the deviations for each pair of data points.
#
# Product of deviations:
# (-1.714 * 0.143), (-0.714 * 1.143), (1.286 * -0.857), (0.286 * 2.143), (2.286 * -1.857), (-1.714 * 0.143), (0.286 * -0.857)
#
# Step 4: Calculate the sum of the products of deviations.
#
# Sum of products of deviations = (-1.714 * 0.143) + (-0.714 * 1.143) + (1.286 * -0.857) + (0.286 * 2.143) + (2.286 * -1.857) + (-1.714 * 0.143) + (0.286 * -0.857) ≈ -1.952
#
# Step 5: Calculate the squared deviations of employee tenure.
#
# Squared deviation of employee tenure:
# (-1.714)^2, (-0.714)^2, (1.286)^2, (0.286)^2, (2.286)^2, (-1.714)^2, (0.286)^2
#
# Step 6: Calculate the sum of the squared deviations of employee tenure.
#
# Sum of squared deviations of employee tenure = (-1.714)^2 + (-0.714)^2 + (1.286)^2 + (0.286)^2 + (2.286)^2 + (-1.714)^2 + (0.286)^2 ≈ 16.619
#
# Step 7: Calculate the slope (β1) of the linear regression line.
#
# Slope (β1) = Sum of products of deviations / Sum of squared deviations of employee tenure = -1.952 / 16.619 ≈ -0.1175
#
# Step 8: Calculate the y-intercept (β0) of the linear regression line.
#
# y-intercept (β0) = Mean of job satisfaction - (Slope * Mean of employee tenure) = 6.857 - (-0.1175 * 3.714) ≈ 7.308
#
# Step 9: Write the equation of the linear regression line.
#
# The equation of the linear regression line is:
# Job Satisfaction = β0 + β1 * Employee Tenure
#
# Substituting the calculated values:
# Job Satisfaction ≈ 7.308 - 0.1175 * Employee Tenure
#
# Therefore, the linear regression analysis predicts job satisfaction based on employee tenure using the equation: Job Satisfaction ≈ 7.308 - 0.1175 * Employee Tenure.

# %% [markdown]
# *9.*
#
# To perform an analysis of variance (ANOVA) and determine if there is a significant difference in the mean recovery times between the two medications, you can use the one-way ANOVA test. The one-way ANOVA test compares the means of multiple groups to see if there is a statistically significant difference between them. Here's how you can perform the ANOVA test using the given data for Medication A and Medication B:
#
# Medication A: [10, 12, 14, 11, 13]
# Medication B: [15, 17, 16, 14, 18]
#
# Step 1: Calculate the means of recovery times for each medication.
#
# Mean recovery time for Medication A:
# (10 + 12 + 14 + 11 + 13) / 5 = 60 / 5 = 12
#
# Mean recovery time for Medication B:
# (15 + 17 + 16 + 14 + 18) / 5 = 80 / 5 = 16
#
# Step 2: Calculate the sum of squares between groups (SSB).
#
# SSB = (n1 * (mean1 - overall_mean)^2) + (n2 * (mean2 - overall_mean)^2)
#    = (5 * (12 - 14)^2) + (5 * (16 - 14)^2)
#    = (5 * (-2)^2) + (5 * 2^2)
#    = 20 + 20
#    = 40
#
# Step 3: Calculate the sum of squares within groups (SSW).
#
# SSW = (n1 - 1) * variance1 + (n2 - 1) * variance2
#    = (5 - 1) * [(10 - 12)^2 + (12 - 12)^2 + (14 - 12)^2 + (11 - 12)^2 + (13 - 12)^2] + (5 - 1) * [(15 - 16)^2 + (17 - 16)^2 + (16 - 16)^2 + (14 - 16)^2 + (18 - 16)^2]
#    = 4 * [(-2)^2 + 0^2 + 2^2 + (-1)^2 + 1^2] + 4 * [(-1)^2 + 1^2 + 0^2 + (-2)^2 + 2^2]
#    = 4 * [4 + 0 + 4 + 1 + 1] + 4 * [1 + 1 + 0 + 4 + 4]
#    = 4 * 10 + 4 * 10
#    = 40 + 40
#    = 80
#
# Step 4: Calculate the degrees of freedom for between groups (dfB).
#
# dfB = number_of_groups - 1
#    = 2 - 1
#    = 1
#
# Step 5: Calculate the degrees of freedom for within groups (dfW).
#
# dfW = total_number_of_observations - number_of_groups
#    = 10 - 2
#    = 8
#
# Step 6: Calculate the mean squares between groups (MSB).
#
# MSB = SSB / dfB
#    = 40 / 1
#    = 40
#
# Step 7: Calculate the mean squares within groups (MSW).
#
# MSW = SSW / dfW
#    = 80 / 8
#    = 10
#
# Step 8: Calculate the F-statistic.
#
# F = MSB / MSW
#    = 40 / 10
#    = 4
#
# Step 9: Determine the critical F-value at the desired significance level (e.g., 0.05) and degrees of freedom (dfB and dfW).
#
# Step 10: Compare the calculated F-value with the critical F-value and determine if there is a significant difference in mean recovery times between the two medications.
#
# If the calculated F-value is greater than the critical F-value, then there is a significant difference between the mean recovery times of the two medications. If the calculated F-value is less than the critical F-value, then there is no significant difference.
#
# Note: Since the critical F-value is not provided in the given scenario, you would need to consult an F-table or use statistical software to determine the critical F-value at the desired significance level and degrees of freedom.

# %% [markdown]
# *10.*
#
# To calculate the 75th percentile of the feedback ratings, you need to find the value below which 75% of the data falls. Here's how you can calculate it using the given data:
#
# Data: [8, 9, 7, 6, 8, 10, 9, 8, 7, 8]
#
# Step 1: Sort the data in ascending order: [6, 7, 7, 8, 8, 8, 8, 9, 9, 10]
#
# Step 2: Calculate the index position of the 75th percentile.
# Index position = (75/100) * (n + 1)
#               = (75/100) * (10 + 1)
#               = (75/100) * 11
#               = 8.25
#
# Step 3: Determine the values at index positions 8 and 9 (since index positions are zero-based).
# Value at index position 8: 9
# Value at index position 9: 9
#
# Step 4: Calculate the weighted average of the values at index positions 8 and 9 to get the 75th percentile.
# 75th percentile = Value at index position 8 + (Index position - 8) * (Value at index position 9 - Value at index position 8)
#                 = 9 + (8.25 - 8) * (9 - 9)
#                 = 9
#
# Therefore, the 75th percentile of the feedback ratings is 9.

# %% [markdown]
# *11.*
#
# To perform a hypothesis test to determine if the mean weight differs significantly from 10 grams, you can use a one-sample t-test. The one-sample t-test compares the mean of a sample to a specified value. Here's how you can perform the hypothesis test using the given data:
#
# Weights of the sample: [10.2, 9.8, 10.0, 10.5, 10.3, 10.1]
#
# Step 1: Define the null hypothesis (H0) and alternative hypothesis (H1).
#
# Null hypothesis (H0): The mean weight is equal to 10 grams.
# Alternative hypothesis (H1): The mean weight differs significantly from 10 grams.
#
# Step 2: Set the significance level (α) for the test. This determines the threshold for rejecting the null hypothesis. Let's assume α = 0.05.
#
# Step 3: Calculate the sample mean and sample standard deviation.
#
# Sample mean (x̄) = (10.2 + 9.8 + 10.0 + 10.5 + 10.3 + 10.1) / 6 = 60.9 / 6 = 10.15
#
# Sample standard deviation (s) = sqrt(((10.2 - 10.15)^2 + (9.8 - 10.15)^2 + (10.0 - 10.15)^2 + (10.5 - 10.15)^2 + (10.3 - 10.15)^2 + (10.1 - 10.15)^2) / (6 - 1))
#                             = sqrt((0.0225 + 0.0225 + 0.0225 + 0.1056 + 0.0075 + 0.0075) / 5)
#                             = sqrt(0.0387 / 5)
#                             = sqrt(0.00774)
#                             ≈ 0.088
#
# Step 4: Calculate the t-value using the formula:
# t = (x̄ - μ) / (s / sqrt(n))
# where μ is the specified value, s is the sample standard deviation, and n is the sample size.
#
# t = (10.15 - 10) / (0.088 / sqrt(6))
#    ≈ 0.15 / (0.088 / 2.449)
#    ≈ 0.15 / 0.036
#    ≈ 4.167
#
# Step 5: Determine the degrees of freedom (df) using the formula:
# df = n - 1
#    = 6 - 1
#    = 5
#
# Step 6: Determine the critical t-value at the desired significance level (α) and degrees of freedom (df).
#
# Step 7: Compare the calculated t-value with the critical t-value and determine if the mean weight differs significantly from 10 grams.
#
# If the calculated t-value falls within the critical region (i.e., it exceeds the critical t-value), then we reject the null hypothesis and conclude that the mean weight differs significantly from 10 grams. If the calculated t-value does not exceed the critical t-value, then we fail to reject the null hypothesis and do not have sufficient evidence to conclude a significant difference.
#
# Note: Since the critical t-value and the degrees of freedom are not provided in the given scenario, you would need to consult a t-table or use statistical software to determine the critical t-value at the desired significance level and degrees of freedom.

# %% [markdown]
# *12.*
#
# To perform a chi-square test to determine if there is a significant difference in the click-through rates between two designs, you can use the chi-square test for independence. The chi-square test for independence assesses whether there is a relationship between two categorical variables. Here's how you can perform the chi-square test using the given data for Design A and Design B:
#
# Design A: [100, 120, 110, 90, 95]
# Design B: [80, 85, 90, 95, 100]
#
# Step 1: Create a contingency table with the observed frequencies.
#
#             Design A     Design B
# -------------------------------------
# Clicks      100           80
#             120           85
#             110           90
#              90           95
#              95           100
#
# Step 2: Calculate the expected frequencies under the assumption of independence.
#
# To calculate the expected frequencies, we need to find the total number of clicks for each design and the total number of observations.
#
# Total number of clicks for Design A: 100 + 120 + 110 + 90 + 95 = 515
# Total number of clicks for Design B: 80 + 85 + 90 + 95 + 100 = 450
# Total number of observations: 5 (since there are 5 data points for each design)
#
# Expected frequency for each cell = (Total clicks for the respective design / Total number of observations) * (Total clicks for the respective cell / Total number of clicks for the respective design)
#
# Expected frequencies for each cell in the contingency table:
#
#             Design A     Design B
# -------------------------------------
# Clicks      (515/5) * (100/515)      (450/5) * (100/450)
#             (515/5) * (120/515)      (450/5) * (120/450)
#             (515/5) * (110/515)      (450/5) * (110/450)
#             (515/5) * (90/515)       (450/5) * (90/450)
#             (515/5) * (95/515)       (450/5) * (95/450)
#
# Step 3: Calculate the chi-square test statistic.
#
# Chi-square test statistic = Σ((Observed frequency - Expected frequency)^2 / Expected frequency)
#
# Sum over all cells in the contingency table:
# ((100 - expected frequency for cell)^2 / expected frequency for cell) +
# ((120 - expected frequency for cell)^2 / expected frequency for cell) +
# ((110 - expected frequency for cell)^2 / expected frequency for cell) +
# ((90 - expected frequency for cell)^2 / expected frequency for cell) +
# ((95 - expected frequency for cell)^2 / expected frequency for cell) +
# ((80 - expected frequency for cell)^2 / expected frequency for cell) +
# ((85 - expected frequency for cell)^2 / expected frequency for cell) +
# ((90 - expected frequency for cell)^2 / expected frequency for cell) +
# ((95 - expected frequency for cell)^2 / expected frequency for cell) +
# ((100 - expected frequency for cell)^2 / expected frequency for cell)
#
# Step 4: Determine the degrees of freedom (df) using the formula:
# df = (number of rows - 1) * (number of columns - 1)
#
# In this case, df = (2 - 1) * (5 - 1) = 1 * 4 = 4
#
# Step 5: Determine the critical chi-square value at the desired significance level (α) and degrees of freedom (df).
#
# Step 6: Compare the calculated chi-square test statistic with the critical chi-square value and determine if there is a significant difference in the click-through rates between the two designs.
#
# If the calculated chi-square test statistic is greater than the critical chi-square value, then there is a significant difference in the click-through rates between the two designs. If the calculated chi-square test statistic is less than the critical chi-square value, then there is no significant difference.
#
# Note: Since the critical chi-square value and the degrees of freedom are not provided in the given scenario, you would need to consult a chi-square table or use statistical software to determine the critical chi-square value at the desired significance level and degrees of freedom.

# %% [markdown]
# *13.*
#
# To calculate the 95% confidence interval for the population mean satisfaction score, you can use the t-distribution. Here's how you can calculate it using the given data:
#
# Data: [7, 9, 6, 8, 10, 7, 8, 9, 7, 8]
#
# Step 1: Calculate the sample mean and sample standard deviation.
#
# Sample mean (x̄) = (7 + 9 + 6 + 8 + 10 + 7 + 8 + 9 + 7 + 8) / 10 = 79 / 10 = 7.9
#
# Sample standard deviation (s) = sqrt(((7 - 7.9)^2 + (9 - 7.9)^2 + (6 - 7.9)^2 + (8 - 7.9)^2 + (10 - 7.9)^2 + (7 - 7.9)^2 + (8 - 7.9)^2 + (9 - 7.9)^2 + (7 - 7.9)^2 + (8 - 7.9)^2) / (10 - 1))
#                             = sqrt((0.81 + 1.21 + 3.61 + 0.01 + 2.89 + 0.81 + 0.01 + 1.21 + 0.81 + 0.01) / 9)
#                             = sqrt(11.67 / 9)
#                             = sqrt(1.30)
#                             ≈ 1.14
#
# Step 2: Determine the critical value from the t-distribution for a 95% confidence level and degrees of freedom (df) of n - 1.
#
# Degrees of freedom (df) = 10 - 1 = 9
#
# Critical value = t_(α/2, df)
#               = t_(0.025, 9)
#
# You can look up the critical value from the t-distribution table or use statistical software to find it. For a two-tailed test and a 95% confidence level with 9 degrees of freedom, the critical value is approximately 2.262.
#
# Step 3: Calculate the margin of error (E).
#
# Margin of error (E) = Critical value * (Sample standard deviation / sqrt(n))
#                    = 2.262 * (1.14 / sqrt(10))
#                    ≈ 2.262 * (1.14 / 3.162)
#                    ≈ 2.262 * 0.360
#                    ≈ 0.816
#
# Step 4: Calculate the lower and upper bounds of the confidence interval.
#
# Lower bound = Sample mean - Margin of error
#             = 7.9 - 0.816
#             ≈ 7.084
#
# Upper bound = Sample mean + Margin of error
#             = 7.9 + 0.816
#             ≈ 8.716
#
# Therefore, the 95% confidence interval for the population mean satisfaction score is approximately 7.084 to 8.716.

# %% [markdown]
# *14.*
#
# To perform a simple linear regression to predict performance based on temperature, you can use the least squares method. Here's how you can do it using the given data:
#
# Temperature (in degrees Celsius): [20, 22, 23, 19, 21]
# Performance (on a scale of 1 to 10): [8, 7, 9, 6, 8]
#
# Step 1: Calculate the means of both temperature and performance.
#
# Mean of temperature:
# (20 + 22 + 23 + 19 + 21) / 5 = 105 / 5 = 21
#
# Mean of performance:
# (8 + 7 + 9 + 6 + 8) / 5 = 38 / 5 = 7.6
#
# Step 2: Calculate the deviations from the means for both variables.
#
# Deviation of temperature:
# 20 - 21 = -1
# 22 - 21 = 1
# 23 - 21 = 2
# 19 - 21 = -2
# 21 - 21 = 0
#
# Deviation of performance:
# 8 - 7.6 = 0.4
# 7 - 7.6 = -0.6
# 9 - 7.6 = 1.4
# 6 - 7.6 = -1.6
# 8 - 7.6 = 0.4
#
# Step 3: Calculate the product of the deviations for each pair of data points.
#
# Product of deviations:
# (-1 * 0.4), (1 * -0.6), (2 * 1.4), (-2 * -1.6), (0 * 0.4)
#
# Step 4: Calculate the sum of the products of deviations.
#
# Sum of products of deviations = (-1 * 0.4) + (1 * -0.6) + (2 * 1.4) + (-2 * -1.6) + (0 * 0.4) = -0.4 - 0.6 + 2.8 + 3.2 + 0 = 4
#
# Step 5: Calculate the squared deviations of temperature.
#
# Squared deviation of temperature:
# (-1)^2, (1)^2, (2)^2, (-2)^2, (0)^2
#
# Step 6: Calculate the sum of the squared deviations of temperature.
#
# Sum of squared deviations of temperature = (-1)^2 + (1)^2 + (2)^2 + (-2)^2 + (0)^2 = 1 + 1 + 4 + 4 + 0 = 10
#
# Step 7: Calculate the slope (β1) of the linear regression line.
#
# Slope (β1) = Sum of products of deviations / Sum of squared deviations of temperature = 4 / 10 = 0.4
#
# Step 8: Calculate the y-intercept (β0) of the linear regression line.
#
# y-intercept (β0) = Mean of performance - (Slope * Mean of temperature) = 7.6 - (0.4 * 21) = 7.6 - 8.4 = -0.8
#
# Step 9: Write the equation of the linear regression line.
#
# The equation of the linear regression line is:
# Performance = β0 + β1 * Temperature
#
# Substituting the calculated values:
# Performance = -0.8 + 0.4 * Temperature
#
# Therefore, the simple linear regression analysis predicts performance based on temperature using the equation: Performance = -0.8 + 0.4 * Temperature.

# %% [markdown]
# *15.*
#
# To perform a Mann-Whitney U test to determine if there is a significant difference in the median preferences between two groups, you can use the Mann-Whitney U test. The Mann-Whitney U test is a non-parametric test that compares the distributions of two independent groups. Here's how you can perform the Mann-Whitney U test using the given data for Group A and Group B:
#
# Group A: [4, 3, 5, 2, 4]
# Group B: [3, 2, 4, 3, 3]
#
# Step 1: Combine the data from both groups and assign ranks to the observations.
#
# Combined data: [4, 3, 5, 2, 4, 3, 2, 4, 3, 3]
#
# Ranks: [7, 2.5, 10, 1, 7, 2.5, 1, 7, 2.5, 2.5]
#
# Step 2: Calculate the sum of ranks for each group.
#
# Sum of ranks for Group A = 7 + 2.5 + 10 + 1 + 7 = 27.5
# Sum of ranks for Group B = 2.5 + 1 + 7 + 2.5 + 2.5 = 16.5
#
# Step 3: Calculate the U statistic for each group.
#
# U statistic for Group A = n1 * n2 + (n1 * (n1 + 1)) / 2 - sum of ranks for Group A
#                         = 5 * 5 + (5 * (5 + 1)) / 2 - 27.5
#                         = 25 + (5 * 6) / 2 - 27.5
#                         = 25 + 15 / 2 - 27.5
#                         = 25 + 7.5 - 27.5
#                         = 32.5 - 27.5
#                         = 5
#
# U statistic for Group B = n1 * n2 + (n1 * (n1 + 1)) / 2 - sum of ranks for Group B
#                         = 5 * 5 + (5 * (5 + 1)) / 2 - 16.5
#                         = 25 + (5 * 6) / 2 - 16.5
#                         = 25 + 15 / 2 - 16.5
#                         = 25 + 7.5 - 16.5
#                         = 32.5 - 16.5
#                         = 16
#
# Step 4: Determine the smaller U value (Umin).
#
# Umin = min(U statistic for Group A, U statistic for Group B) = min(5, 16) = 5
#
# Step 5: Calculate the expected value of U (E(U)).
#
# E(U) = (n1 * n2) / 2 = (5 * 5) / 2 = 12.5
#
# Step 6: Calculate the standard deviation of U (SD(U)).
#
# SD(U) = sqrt((n1 * n2 * (n1 + n2 + 1)) / 12)
#       = sqrt((5 * 5 * (5 + 5 + 1)) / 12)
#       = sqrt((125) / 12)
#       ≈ 3.07
#
# Step 7: Calculate the z-score.
#
# z = (Umin - E(U)) / SD(U) = (5 - 12.5) / 3.07 ≈ -2.45
#
# Step 8: Determine the critical z-value at the desired significance level (α).
#
# Step 9: Compare the calculated z-score with the critical z-value and determine if there is a significant difference in the median preferences between the two groups.
#
# If the calculated z-score falls within the critical region (i.e., it exceeds the critical z-value), then we reject the null hypothesis and conclude that there is a significant difference in the median preferences between the two groups. If the calculated z-score does not exceed the critical z-value, then we fail to reject the null hypothesis and do not have sufficient evidence to conclude a significant difference.
#
# Note: Since the critical z-value and the significance level (α) are not provided in the given scenario, you would need to consult a z-table or use statistical software to determine the critical z-value at the desired significance level.

# %% [markdown]
# *16.*
#
# To calculate the interquartile range (IQR) of the ages, you need to find the difference between the 75th percentile (Q3) and the 25th percentile (Q1) of the data. Here's how you can calculate it using the given data:
#
# Data: [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
#
# Step 1: Sort the data in ascending order: [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
#
# Step 2: Calculate the index positions of the 25th and 75th percentiles.
#
# Index position of Q1 = (25/100) * (n + 1)
#                     = (25/100) * (10 + 1)
#                     = (25/100) * 11
#                     = 2.75
#                     ≈ 2 (since index positions are whole numbers)
#
# Index position of Q3 = (75/100) * (n + 1)
#                     = (75/100) * (10 + 1)
#                     = (75/100) * 11
#                     = 8.25
#                     ≈ 8 (since index positions are whole numbers)
#
# Step 3: Determine the values at index positions 2 and 8 (since index positions are zero-based).
#
# Value at index position 2: 35
# Value at index position 8: 60
#
# Step 4: Calculate the difference between Q3 and Q1 to get the interquartile range (IQR).
# IQR = Q3 - Q1 = 60 - 35 = 25
#
# Therefore, the interquartile range (IQR) of the ages is 25.

# %% [markdown]
# *17.*
#
# To perform a Kruskal-Wallis test to determine if there is a significant difference in the median accuracy scores between the three algorithms, you can use the Kruskal-Wallis test. The Kruskal-Wallis test is a non-parametric test that compares the distributions of three or more independent groups. Here's how you can perform the Kruskal-Wallis test using the given data for Algorithm A, Algorithm B, and Algorithm C:
#
# Algorithm A: [0.85, 0.80, 0.82, 0.87, 0.83]
# Algorithm B: [0.78, 0.82, 0.84, 0.80, 0.79]
# Algorithm C: [0.90, 0.88, 0.89, 0.86, 0.87]
#
# Step 1: Combine the data from all three algorithms.
#
# Combined data: [0.85, 0.80, 0.82, 0.87, 0.83, 0.78, 0.82, 0.84, 0.80, 0.79, 0.90, 0.88, 0.89, 0.86, 0.87]
#
# Step 2: Assign ranks to the observations in the combined data, considering ties.
#
# Ranks: [11, 4, 7, 13, 8, 1, 7, 9, 4, 2, 15, 12, 14, 10, 13]
#
# Step 3: Calculate the sum of ranks for each group.
#
# Sum of ranks for Algorithm A = 11 + 4 + 7 + 13 + 8 = 43
# Sum of ranks for Algorithm B = 1 + 7 + 9 + 4 + 2 = 23
# Sum of ranks for Algorithm C = 15 + 12 + 14 + 10 + 13 = 64
#
# Step 4: Calculate the test statistic (H) using the formula:
#
# H = (12 * (Sum of ranks for each group)^2) / (n * (n + 1)) - 3 * (n + 1)
#
# where n is the total number of observations.
#
# n = 15 (since there are 15 observations in the combined data)
#
# H = (12 * (43^2 + 23^2 + 64^2)) / (15 * (15 + 1)) - 3 * (15 + 1)
#   = (12 * (1849 + 529 + 4096)) / (15 * 16) - 3 * 16
#   = (12 * 6474) / 240 - 48
#   = 1734.48 - 48
#   = 1686.48
#
# Step 5: Determine the critical chi-square value at the desired significance level (α) and degrees of freedom (k - 1, where k is the number of groups).
#
# Degrees of freedom (df) = k - 1 = 3 - 1 = 2
#
# Step 6: Compare the calculated test statistic (H) with the critical chi-square value and determine if there is a significant difference in the median accuracy scores between the algorithms.
#
# If the calculated test statistic (H) exceeds the critical chi-square value, then we reject the null hypothesis and conclude that there is a significant difference in the median accuracy scores between the algorithms. If the calculated test statistic (H) does not exceed the critical chi-square value, then we fail to reject the null hypothesis and do not have sufficient evidence to conclude a significant difference.
#
# Note: Since the critical chi-square value and the significance level (α) are not provided in the given scenario, you would need to consult a chi-square table or use statistical software to determine the critical chi-square value at the desired significance level and degrees of freedom.

# %% [markdown]
# *18.*
#
# To perform a simple linear regression to predict sales based on price, you can use the least squares method. Here's how you can do it using the given data:
#
# Price (in dollars): [10, 15, 12, 8, 14]
# Sales: [100, 80, 90, 110, 95]
#
# Step 1: Calculate the means of both price and sales.
#
# Mean of price:
# (10 + 15 + 12 + 8 + 14) / 5 = 59 / 5 = 11.8
#
# Mean of sales:
# (100 + 80 + 90 + 110 + 95) / 5 = 475 / 5 = 95
#
# Step 2: Calculate the deviations from the means for both variables.
#
# Deviation of price:
# 10 - 11.8 = -1.8
# 15 - 11.8 = 3.2
# 12 - 11.8 = 0.2
# 8 - 11.8 = -3.8
# 14 - 11.8 = 2.2
#
# Deviation of sales:
# 100 - 95 = 5
# 80 - 95 = -15
# 90 - 95 = -5
# 110 - 95 = 15
# 95 - 95 = 0
#
# Step 3: Calculate the product of the deviations for each pair of data points.
#
# Product of deviations:
# (-1.8 * 5), (3.2 * -15), (0.2 * -5), (-3.8 * 15), (2.2 * 0)
#
# Step 4: Calculate the sum of the products of deviations.
#
# Sum of products of deviations = (-1.8 * 5) + (3.2 * -15) + (0.2 * -5) + (-3.8 * 15) + (2.2 * 0) = -9 - 48 - 1 - 57 - 0 = -115
#
# Step 5: Calculate the squared deviations of price.
#
# Squared deviation of price:
# (-1.8)^2, (3.2)^2, (0.2)^2, (-3.8)^2, (2.2)^2
#
# Step 6: Calculate the sum of the squared deviations of price.
#
# Sum of squared deviations of price = (-1.8)^2 + (3.2)^2 + (0.2)^2 + (-3.8)^2 + (2.2)^2 = 3.24 + 10.24 + 0.04 + 14.44 + 4.84 = 32.8
#
# Step 7: Calculate the slope (β1) of the linear regression line.
#
# Slope (β1) = Sum of products of deviations / Sum of squared deviations of price = -115 / 32.8 ≈ -3.51
#
# Step 8: Calculate the y-intercept (β0) of the linear regression line.
#
# y-intercept (β0) = Mean of sales - (Slope * Mean of price) = 95 - (-3.51 * 11.8) ≈ 95 + 41.52 ≈ 136.52
#
# Step 9: Write the equation of the linear regression line.
#
# The equation of the linear regression line is:
# Sales = β0 + β1 * Price
#
# Substituting the calculated values:
# Sales = 136.52 - 3.51 * Price
#
# Therefore, the simple linear regression analysis predicts sales based on price using the equation: Sales = 136.52 - 3.51 * Price.

# %% [markdown]
# *19.*
#
# To calculate the standard error of the mean satisfaction score, you need to divide the standard deviation by the square root of the sample size. Here's how you can calculate it using the given data:
#
# Data: [7, 8, 9, 6, 8, 7, 9, 7, 8, 7]
#
# Step 1: Calculate the sample mean.
#
# Sample mean (x̄) = (7 + 8 + 9 + 6 + 8 + 7 + 9 + 7 + 8 + 7) / 10 = 76 / 10 = 7.6
#
# Step 2: Calculate the deviations from the sample mean.
#
# Deviation of each data point from the mean:
# 7 - 7.6 = -0.6
# 8 - 7.6 = 0.4
# 9 - 7.6 = 1.4
# 6 - 7.6 = -1.6
# 8 - 7.6 = 0.4
# 7 - 7.6 = -0.6
# 9 - 7.6 = 1.4
# 7 - 7.6 = -0.6
# 8 - 7.6 = 0.4
# 7 - 7.6 = -0.6
#
# Step 3: Calculate the squared deviations.
#
# Squared deviation of each data point from the mean:
# (-0.6)^2, (0.4)^2, (1.4)^2, (-1.6)^2, (0.4)^2, (-0.6)^2, (1.4)^2, (-0.6)^2, (0.4)^2, (-0.6)^2
#
# Step 4: Calculate the sum of squared deviations.
#
# Sum of squared deviations = (-0.6)^2 + (0.4)^2 + (1.4)^2 + (-1.6)^2 + (0.4)^2 + (-0.6)^2 + (1.4)^2 + (-0.6)^2 + (0.4)^2 + (-0.6)^2
#
# Step 5: Calculate the sample variance.
#
# Sample variance (s^2) = Sum of squared deviations / (n - 1) = Sum of squared deviations / (10 - 1) = Sum of squared deviations / 9
#
# Step 6: Calculate the standard deviation.
#
# Sample standard deviation (s) = sqrt(sample variance)
#
# Step 7: Calculate the standard error of the mean.
#
# Standard error of the mean (SE) = Sample standard deviation / sqrt(sample size)
#
# Therefore, to calculate the standard error of the mean satisfaction score, you would need to calculate the sample variance, sample standard deviation, and sample size using the given data.

# %% [markdown]
# *20.*
#
# To perform a multiple regression analysis to predict sales based on advertising expenditure, you can use the least squares method. Here's how you can do it using the given data:
#
# Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
# Sales (in thousands): [25, 30, 28, 20, 26]
#
# Step 1: Create a matrix of the predictor variable (advertising expenditure) and the response variable (sales).
#
# Advertising Expenditure (X): [10, 15, 12, 8, 14]
# Sales (Y): [25, 30, 28, 20, 26]
#
# Step 2: Calculate the means of both advertising expenditure (X) and sales (Y).
#
# Mean of X:
# (10 + 15 + 12 + 8 + 14) / 5 = 59 / 5 = 11.8
#
# Mean of Y:
# (25 + 30 + 28 + 20 + 26) / 5 = 129 / 5 = 25.8
#
# Step 3: Calculate the deviations from the means for both variables.
#
# Deviation of X:
# 10 - 11.8 = -1.8
# 15 - 11.8 = 3.2
# 12 - 11.8 = 0.2
# 8 - 11.8 = -3.8
# 14 - 11.8 = 2.2
#
# Deviation of Y:
# 25 - 25.8 = -0.8
# 30 - 25.8 = 4.2
# 28 - 25.8 = 2.2
# 20 - 25.8 = -5.8
# 26 - 25.8 = 0.2
#
# Step 4: Calculate the product of the deviations for each pair of data points.
#
# Product of deviations:
# (-1.8 * -0.8), (3.2 * 4.2), (0.2 * 2.2), (-3.8 * -5.8), (2.2 * 0.2)
#
# Step 5: Calculate the sum of the products of deviations.
#
# Sum of products of deviations = (-1.8 * -0.8) + (3.2 * 4.2) + (0.2 * 2.2) + (-3.8 * -5.8) + (2.2 * 0.2) = 1.44 + 13.44 + 0.44 + 22.04 + 0.44 = 37.8
#
# Step 6: Calculate the squared deviations of X.
#
# Squared deviation of X:
# (-1.8)^2, (3.2)^2, (0.2)^2, (-3.8)^2, (2.2)^2
#
# Step 7: Calculate the sum of the squared deviations of X.
#
# Sum of squared deviations of X = (-1.8)^2 + (3.2)^2 + (0.2)^2 + (-3.8)^2 + (2.2)^2 = 3.24 + 10.24 + 0.04 + 14.44 + 4.84 = 32.8
#
# Step 8: Calculate the slope (β1) of the regression line.
#
# Slope (β1) = Sum of products of deviations / Sum of squared deviations of X = 37.8 / 32.8 ≈ 1.152
#
# Step 9: Calculate the y-intercept (β0) of the regression line.
#
# y-intercept (β0) = Mean of Y - (Slope * Mean of X) = 25.8 - (1.152 * 11.8) ≈ 25.8 - 13.6416 ≈ 12.1584
#
# Step 10: Write the equation of the regression line.
#
# The equation of the regression line is:
# Sales = β0 + β1 * Advertising Expenditure
#
# Substituting the calculated values:
# Sales = 12.1584 + 1.152 * Advertising Expenditure
#
# Therefore, the multiple regression analysis predicts sales based on advertising expenditure using the equation: Sales = 12.1584 + 1.152 * Advertising Expenditure.
